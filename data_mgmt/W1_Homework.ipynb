# %%
import numpy as np
import random
import pandas as pd

import os as os

# %%
df = pd.DataFrame(np.random.rand(5, 3),
columns=['A', 'B', 'C'])
df.plot(kind='bar', grid=True)
# Out:
# <AxesSubplot:>

# %%
# pulling from datasets folder
my_bank_data = pd.read_excel(r'datasets\bank_data.xlsx')

# %%
#how to write to excel
#my_bank_data.to_excel(r'my_exported_excel_data.xlsx')

# %%
my_bank_data.head(5)
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
from IPython.display import display
from PIL import Image

# %%
my_OSU_Campus = Image.open(r'OSU.jpg')

# %%
display(my_OSU_Campus)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=959x639>

# %%
#export image
my_OSU_Campus.save(r'my_exported_OSU_Campus.jpg')

# %%
my_bank_data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
my_bank_data.columns.values.tolist()
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
sorted(my_bank_data.columns.values.tolist())
# Out:
# ['age',
#  'balance',
#  'campaign',
#  'contact',
#  'day',
#  'default',
#  'duration',
#  'education',
#  'housing',
#  'job',
#  'loan',
#  'marital',
#  'month',
#  'pdays',
#  'poutcome',
#  'previous',
#  'y']

# %%
my_b_list = my_bank_data.columns.values.tolist()
sorted(my_b_list)
# Out:
# ['age',
#  'balance',
#  'campaign',
#  'contact',
#  'day',
#  'default',
#  'duration',
#  'education',
#  'housing',
#  'job',
#  'loan',
#  'marital',
#  'month',
#  'pdays',
#  'poutcome',
#  'previous',
#  'y']

# %%
my_bank_data.head(5)
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
#8.a
my_bank_data[4:7]
# Out:
#    age         job  marital education default  balance housing loan  contact  \
# 4   33     unknown   single   unknown      no        1      no   no  unknown
# 5   35  management  married  tertiary      no      231     yes   no  unknown
# 6   28  management   single  tertiary      no      447     yes  yes  unknown
#
#    day month  duration  campaign  pdays  previous poutcome   y
# 4    5   may       198         1     -1         0  unknown  no
# 5    5   may       139         1     -1         0  unknown  no
# 6    5   may       217         1     -1         0  unknown  no

# %%
#8.b
my_bank_data[['age', 'job', 'marital', 'education']]
# Out:
# (15, 17)

# %%
#8.c
my_bank_data.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
#8.d
my_bank_data.shape
# Out:
# (15, 17)

# %%
my_list = ['car', 'mountain', 345, 789]

# %%
type(my_list)
# Out:
# list

# %%
my_tuple = ('car', 'mountain', 345, 789)

# %%
type(my_tuple)
# Out:
# tuple

# %%
data_dict = {
    "continents": ['Europe', 'Africa', 'South America'],
    "countries": ['Albania', 'Angola', 'Argentina'],
    "capitals": ['Tirana', 'Luanda', 'Buenos Aires']
}

data_frame = pd.DataFrame(data_dict)

# %%
type(data_dict)
# Out:
# dict

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
#This script will generate a bar chart using random numbers.

"""This script will generate a bar chart using random numbers."""

"""This script 
will generate a 
bar chart using 
random numbers."""


df = pd.DataFrame(np.random.rand(5, 3),
columns=['A', 'B', 'C'])
df.plot(kind='bar', grid=True)
# Out:
# <AxesSubplot:>
